# %%
from google_images_search import GoogleImagesSearch

# %%
# you can provide API key and CX using arguments,
# or you can set environment variables: GCS_DEVELOPER_KEY, GCS_CX
gis = GoogleImagesSearch('AIzaSyAbTRtQbGYNiw5maBrqC7zfrOMeYQ8OGe8', 'a3e61cb8e8e254222')

# define search params
# option for commonly used search param are shown below for easy reference.
# For param marked with '##':
#   - Multiselect is currently not feasible. Choose ONE option only
#   - This param can also be omitted from _search_params if you do not wish to define any value
_search_params = {
    'q': 'Creme La Mer',
    'num': 5,
    'fileType': ['jpg','png'],
    'rights': ['cc_publicdomain','cc_attribute','cc_sharealike','cc_noncommercial','cc_nonderived'],
    'safe': 'active', ##
    'imgType': 'photo', ##
    'imgSize': 'medium', ##
    'imgDominantColor': 'imgDominantColorUndefined', ##
    'imgColorType': 'color' ##
}

# this will only search for images:
gis.search(search_params=_search_params)

for image in gis.results():
    print(image.url)  # image direct url
# Out:
# https://m.media-amazon.com/images/I/61+k2MufjuS._AC_UF350,350_QL80_.jpg
# https://d2rbybg5ibx87t.cloudfront.net/images/55106/original.jpg?1384611234
# https://bluemercury.com/cdn/shop/files/variant_images-size-34oz-747930013549-1_medium.jpg?v=1692642891
# https://n.nordstrommedia.com/id/sr3/b4ec52cb-492d-4659-b647-cc00b06a40da.jpeg?trim=color&pad_color=FFF&format=jpeg&w=350&h=536&trimcolor=FFF
# https://images-na.ssl-images-amazon.com/images/I/71Ax5sR4SUL._AC_UL210_SR210,210_.jpg

# %%
import matplotlib.pyplot as plt 
import requests 
from PIL import Image

image_url = gis.results()[0]

img = Image.open(requests.get(image_url.url, stream=True).raw)
plt.imshow(img)
plt.show()

# %%
def get_url(brand, product):
    gis = GoogleImagesSearch('AIzaSyAbTRtQbGYNiw5maBrqC7zfrOMeYQ8OGe8', 'a3e61cb8e8e254222')

    _search_params = {
        'q': brand + " " + product,
        'num': 5,
        'fileType': ['jpg','png'],
        'rights': ['cc_publicdomain','cc_attribute','cc_sharealike','cc_noncommercial','cc_nonderived'],
        'safe': 'active', ##
        'imgType': 'photo', ##
        'imgSize': 'medium', ##
        'imgDominantColor': 'imgDominantColorUndefined', ##
        'imgColorType': 'color' ##
    }

    # this will only search for images:
    gis.search(search_params=_search_params)

    res = gis.results()

    return res[0].url
